# %%
import ui_module

if __name__ == '__main__':
    ui_module.show_menu()
# Out:
# Loaded 172000 records
#
# ...
# STROKE DATA ANALYTICS
# ...
#
# Queries:
#  1-Smokers+hypertension+stroke
#  2-Heart disease+stroke
#  3-Hypertension by gender
#  4-Smokers by stroke
#  5-Residence by stroke
#  6-Dietary habits
#  7-Hypertension+stroke patients
#  8-All hypertension
#  9-Heart disease+stroke patients
#  10-Age stats
#  11-Sleep hours
#  0-Exit
# Enter query (0-11):  1
# ...
# QUERY 1: Smokers+hypertension+stroke
# ...
# average: 57.64255319148936
# modal: 67.0
# median: 60.0
# ...
# Press Enter...
# ...
# STROKE DATA ANALYTICS
# ...
#
# Queries:
#  1-Smokers+hypertension+stroke
#  2-Heart disease+stroke
#  3-Hypertension by gender
#  4-Smokers by stroke
#  5-Residence by stroke
#  6-Dietary habits
#  7-Hypertension+stroke patients
#  8-All hypertension
#  9-Heart disease+stroke patients
#  10-Age stats
#  11-Sleep hours
#  0-Exit
# Enter query (0-11):  0
